# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from pylab import *

# %%
data1_sin = pd.read_csv("/home/renzo/Documents/RLE/Codigos/rle_127/solo12-pybullet/telemetria/fuerzas_sin_lad1.csv")
data2_sin = pd.read_csv("/home/renzo/Documents/RLE/Codigos/rle_127/solo12-pybullet/telemetria/fuerzas_sin_lad2.csv")
data3_sin = pd.read_csv("/home/renzo/Documents/RLE/Codigos/rle_127/solo12-pybullet/telemetria/fuerzas_sin_lad3.csv")
data4_sin = pd.read_csv("/home/renzo/Documents/RLE/Codigos/rle_127/solo12-pybullet/telemetria/fuerzas_sin_lad4.csv")
data5_sin = pd.read_csv("/home/renzo/Documents/RLE/Codigos/rle_127/solo12-pybullet/telemetria/fuerzas_sin_lad5.csv")
data6_sin = pd.read_csv("/home/renzo/Documents/RLE/Codigos/rle_127/solo12-pybullet/telemetria/fuerzas_sin_lad6.csv")
data7_sin = pd.read_csv("/home/renzo/Documents/RLE/Codigos/rle_127/solo12-pybullet/telemetria/fuerzas_sin_lad7.csv")
data8_sin = pd.read_csv("/home/renzo/Documents/RLE/Codigos/rle_127/solo12-pybullet/telemetria/fuerzas_sin_lad8.csv")
data9_sin = pd.read_csv("/home/renzo/Documents/RLE/Codigos/rle_127/solo12-pybullet/telemetria/fuerzas_sin_lad9.csv")
data10_sin = pd.read_csv("/home/renzo/Documents/RLE/Codigos/rle_127/solo12-pybullet/telemetria/fuerzas_sin_lad10.csv")

data1_bez = pd.read_csv("/home/renzo/Documents/RLE/Codigos/rle_127/solo12-pybullet/telemetria/fuerzas_Bezier_lad_2_1.csv")
data2_bez = pd.read_csv("/home/renzo/Documents/RLE/Codigos/rle_127/solo12-pybullet/telemetria/fuerzas_Bezier_lad_2_2.csv")
data3_bez = pd.read_csv("/home/renzo/Documents/RLE/Codigos/rle_127/solo12-pybullet/telemetria/fuerzas_Bezier_lad_2_3.csv")
data4_bez = pd.read_csv("/home/renzo/Documents/RLE/Codigos/rle_127/solo12-pybullet/telemetria/fuerzas_Bezier_lad_2_4.csv")
data5_bez = pd.read_csv("/home/renzo/Documents/RLE/Codigos/rle_127/solo12-pybullet/telemetria/fuerzas_Bezier_lad_2_5.csv")
data6_bez = pd.read_csv("/home/renzo/Documents/RLE/Codigos/rle_127/solo12-pybullet/telemetria/fuerzas_Bezier_lad_2_6.csv")
data7_bez = pd.read_csv("/home/renzo/Documents/RLE/Codigos/rle_127/solo12-pybullet/telemetria/fuerzas_Bezier_lad_2_7.csv")
data8_bez = pd.read_csv("/home/renzo/Documents/RLE/Codigos/rle_127/solo12-pybullet/telemetria/fuerzas_Bezier_lad_2_8.csv")
data9_bez = pd.read_csv("/home/renzo/Documents/RLE/Codigos/rle_127/solo12-pybullet/telemetria/fuerzas_Bezier_lad_2_9.csv")
data10_bez = pd.read_csv("/home/renzo/Documents/RLE/Codigos/rle_127/solo12-pybullet/telemetria/fuerzas_Bezier_lad_2_10.csv")

data1_cyc = pd.read_csv("/home/renzo/Documents/RLE/Codigos/rle_127/solo12-pybullet/telemetria/data_simple_cicloida/data_ccycloid_lad1.csv")
data2_cyc = pd.read_csv("/home/renzo/Documents/RLE/Codigos/rle_127/solo12-pybullet/telemetria/data_simple_cicloida/data_ccycloid_lad2.csv")
data3_cyc = pd.read_csv("/home/renzo/Documents/RLE/Codigos/rle_127/solo12-pybullet/telemetria/data_simple_cicloida/data_ccycloid_lad3.csv")
data4_cyc = pd.read_csv("/home/renzo/Documents/RLE/Codigos/rle_127/solo12-pybullet/telemetria/data_simple_cicloida/data_ccycloid_lad4.csv")
data5_cyc = pd.read_csv("/home/renzo/Documents/RLE/Codigos/rle_127/solo12-pybullet/telemetria/data_simple_cicloida/data_ccycloid_lad5.csv")
data6_cyc = pd.read_csv("/home/renzo/Documents/RLE/Codigos/rle_127/solo12-pybullet/telemetria/data_simple_cicloida/data_ccycloid_lad6.csv")
data7_cyc = pd.read_csv("/home/renzo/Documents/RLE/Codigos/rle_127/solo12-pybullet/telemetria/data_simple_cicloida/data_ccycloid_lad7.csv")
data8_cyc = pd.read_csv("/home/renzo/Documents/RLE/Codigos/rle_127/solo12-pybullet/telemetria/data_simple_cicloida/data_ccycloid_lad8.csv")
data9_cyc = pd.read_csv("/home/renzo/Documents/RLE/Codigos/rle_127/solo12-pybullet/telemetria/data_simple_cicloida/data_ccycloid_lad9.csv")
data10_cyc = pd.read_csv("/home/renzo/Documents/RLE/Codigos/rle_127/solo12-pybullet/telemetria/data_simple_cicloida/data_ccycloid_lad10.csv")

data1_simp = pd.read_csv("/home/renzo/Documents/RLE/Codigos/rle_127/solo12-pybullet/telemetria/data_simple_cicloida/data_csimple_lad.csv")
data2_simp = pd.read_csv("/home/renzo/Documents/RLE/Codigos/rle_127/solo12-pybullet/telemetria/data_simple_cicloida/data_csimple_lad2.csv")
data3_simp = pd.read_csv("/home/renzo/Documents/RLE/Codigos/rle_127/solo12-pybullet/telemetria/data_simple_cicloida/data_csimple_lad3.csv")
data4_simp = pd.read_csv("/home/renzo/Documents/RLE/Codigos/rle_127/solo12-pybullet/telemetria/data_simple_cicloida/data_csimple_lad4.csv")
data5_simp = pd.read_csv("/home/renzo/Documents/RLE/Codigos/rle_127/solo12-pybullet/telemetria/data_simple_cicloida/data_csimple_lad5.csv")
data6_simp = pd.read_csv("/home/renzo/Documents/RLE/Codigos/rle_127/solo12-pybullet/telemetria/data_simple_cicloida/data_csimple_lad6.csv")
data7_simp = pd.read_csv("/home/renzo/Documents/RLE/Codigos/rle_127/solo12-pybullet/telemetria/data_simple_cicloida/data_csimple_lad7.csv")
data8_simp = pd.read_csv("/home/renzo/Documents/RLE/Codigos/rle_127/solo12-pybullet/telemetria/data_simple_cicloida/data_csimple_lad8.csv")
data9_simp = pd.read_csv("/home/renzo/Documents/RLE/Codigos/rle_127/solo12-pybullet/telemetria/data_simple_cicloida/data_csimple_lad9.csv")
data10_simp = pd.read_csv("/home/renzo/Documents/RLE/Codigos/rle_127/solo12-pybullet/telemetria/data_simple_cicloida/data_csimple_lad10.csv")

# %%
FR_sin = np.concatenate((data1_sin["FR"][500::],data2_sin["FR"][500::],data3_sin["FR"][500::],
data4_sin["FR"][500::],data5_sin["FR"][500::],data6_sin["FR"][500::],data7_sin["FR"][500::],
data8_sin["FR"][500::],data9_sin["FR"][500::],data10_sin["FR"][500::]))
FR_sin=np.abs(FR_sin)

FR_bez = np.concatenate((data1_bez["FR"][500::],data2_bez["FR"][500::],data3_bez["FR"][500::],
data4_bez["FR"][500::],data5_bez["FR"][500::],data6_bez["FR"][500::],data7_bez["FR"][500::],
data8_bez["FR"][500::],data9_bez["FR"][500::],data10_bez["FR"][500::]))
FR_bez=np.abs(FR_bez)

FR_cyc = np.concatenate((data1_cyc["FR"][500::],data2_cyc["FR"][500::],data3_cyc["FR"][500::],
data4_cyc["FR"][500::],data5_cyc["FR"][500::],data6_cyc["FR"][500::],data7_cyc["FR"][500::],
data8_cyc["FR"][500::],data9_cyc["FR"][500::],data10_cyc["FR"][500::]))
FR_cyc=np.abs(FR_cyc)

FR_simp = np.concatenate((data1_simp["FR"][500::],data2_simp["FR"][500::],data3_simp["FR"][500::],
data4_simp["FR"][500::],data5_simp["FR"][500::],data6_simp["FR"][500::],data7_simp["FR"][500::],
data8_simp["FR"][500::],data9_simp["FR"][500::],data10_simp["FR"][500::]))
FR_simp=np.abs(FR_simp)

data_FR=[FR_sin,FR_bez,FR_cyc,FR_simp]

# %%
FL_sin = np.concatenate((data1_sin["FL"][500::],data2_sin["FL"][500::],data3_sin["FL"][500::],
data4_sin["FL"][500::],data5_sin["FL"][500::],data6_sin["FL"][500::],data7_sin["FL"][500::],
data8_sin["FL"][500::],data9_sin["FL"][500::],data10_sin["FL"][500::]))
FL_sin=np.abs(FL_sin)

FL_bez = np.concatenate((data1_bez["FL"][500::],data2_bez["FL"][500::],data3_bez["FL"][500::],
data4_bez["FL"][500::],data5_bez["FL"][500::],data6_bez["FL"][500::],data7_bez["FL"][500::],
data8_bez["FL"][500::],data9_bez["FL"][500::],data10_bez["FL"][500::]))
FL_bez=np.abs(FL_bez)

FL_cyc = np.concatenate((data1_cyc["FL"][500::],data2_cyc["FL"][500::],data3_cyc["FL"][500::],
data4_cyc["FL"][500::],data5_cyc["FL"][500::],data6_cyc["FL"][500::],data7_cyc["FL"][500::],
data8_cyc["FL"][500::],data9_cyc["FL"][500::],data10_cyc["FL"][500::]))
FL_cyc=np.abs(FL_cyc)

FL_simp = np.concatenate((data1_simp["FL"][500::],data2_simp["FL"][500::],data3_simp["FL"][500::],
data4_simp["FL"][500::],data5_simp["FL"][500::],data6_simp["FL"][500::],data7_simp["FL"][500::],
data8_simp["FL"][500::],data9_simp["FL"][500::],data10_simp["FL"][500::]))
FL_simp=np.abs(FL_simp)

data_FL=[FL_sin,FL_bez,FL_cyc,FL_simp]

# %%
BR_sin = np.concatenate((data1_sin["BR"][500::],data2_sin["BR"][500::],data3_sin["BR"][500::],
data4_sin["BR"][500::],data5_sin["BR"][500::],data6_sin["BR"][500::],data7_sin["BR"][500::],
data8_sin["BR"][500::],data9_sin["BR"][500::],data10_sin["BR"][500::]))
BR_sin=np.abs(BR_sin)

BR_bez = np.concatenate((data1_bez["BR"][500::],data2_bez["BR"][500::],data3_bez["BR"][500::],
data4_bez["BR"][500::],data5_bez["BR"][500::],data6_bez["BR"][500::],data7_bez["BR"][500::],
data8_bez["BR"][500::],data9_bez["BR"][500::],data10_bez["BR"][500::]))
BR_bez=np.abs(BR_bez)

BR_cyc = np.concatenate((data1_cyc["BR"][500::],data2_cyc["BR"][500::],data3_cyc["BR"][500::],
data4_cyc["BR"][500::],data5_cyc["BR"][500::],data6_cyc["BR"][500::],data7_cyc["BR"][500::],
data8_cyc["BR"][500::],data9_cyc["BR"][500::],data10_cyc["BR"][500::]))
BR_cyc=np.abs(BR_cyc)

BR_simp = np.concatenate((data1_simp["BR"][500::],data2_simp["BR"][500::],data3_simp["BR"][500::],
data4_simp["BR"][500::],data5_simp["BR"][500::],data6_simp["BR"][500::],data7_simp["BR"][500::],
data8_simp["BR"][500::],data9_simp["BR"][500::],data10_simp["BR"][500::]))
BR_simp=np.abs(BR_simp)

data_BR=[BR_sin,BR_bez,BR_cyc,BR_simp]

# %%
BL_sin = np.concatenate((data1_sin["BL"][500::],data2_sin["BL"][500::],data3_sin["BL"][500::],
data4_sin["BL"][500::],data5_sin["BL"][500::],data6_sin["BL"][500::],data7_sin["BL"][500::],
data8_sin["BL"][500::],data9_sin["BL"][500::],data10_sin["BL"][500::]))
BL_sin=np.abs(BL_sin)

BL_bez = np.concatenate((data1_bez["BL"][500::],data2_bez["BL"][500::],data3_bez["BL"][500::],
data4_bez["BL"][500::],data5_bez["BL"][500::],data6_bez["BL"][500::],data7_bez["BL"][500::],
data8_bez["BL"][500::],data9_bez["BL"][500::],data10_bez["BL"][500::]))
BL_bez=np.abs(BL_bez)

BL_cyc = np.concatenate((data1_cyc["BL"][500::],data2_cyc["BL"][500::],data3_cyc["BL"][500::],
data4_cyc["BL"][500::],data5_cyc["BL"][500::],data6_cyc["BL"][500::],data7_cyc["BL"][500::],
data8_cyc["BL"][500::],data9_cyc["BL"][500::],data10_cyc["BL"][500::]))
BL_cyc=np.abs(BL_cyc)

BL_simp = np.concatenate((data1_simp["BL"][500::],data2_simp["BL"][500::],data3_simp["BL"][500::],
data4_simp["BL"][500::],data5_simp["BL"][500::],data6_simp["BL"][500::],data7_simp["BL"][500::],
data8_simp["BL"][500::],data9_simp["BL"][500::],data10_simp["BL"][500::]))
BL_simp=np.abs(BL_simp)

data_BL=[BL_sin,BL_bez,BL_cyc,BL_simp]

# %%
def create_boxplot(data, axs, ix, iy, tit):
    bp = axs[ix,iy].boxplot(data, patch_artist = True, vert = 0, notch = 0)

    colors = ['blue','red','green','yellow']
    
    for patch, color in zip(bp['boxes'], colors):
        patch.set_facecolor(color)

    # changing color and linewidth of
    # medians
    for median in bp['medians']:
        median.set(color ='black',
                linewidth = 3)
        x, y = median.get_xydata()[1] # top of median line
        axs[ix,iy].text(x, y+0.05, '%.1f' % x,
            horizontalalignment='center') # draw above, centered
    
    # changing style of fliers
    for flier in bp['fliers']:
        flier.set(marker ='D',
                color ='#e7298a',
                alpha = 0.25)

    # changing color and linewidth of
    # caps
    for cap in bp['caps']:
        cap.set(color = '#8B008B',
                linewidth = 2)

    # changing color and linewidth of
    # whiskers
    for whisker in bp['whiskers']:
        whisker.set(color ='#8B008B',
                    linewidth = 1.5,
                    linestyle =":")

    # Setting limits and labels
    #axs[ix,iy].set_xlim([-5,200])
    axs[ix,iy].set_yticklabels(['Sinusoidal', 'Bezier12','Cycloid','Simple'])
    axs[ix,iy].set_title(tit)
    axs[ix,iy].set_xlabel("Force (N)")

    
    return bp

# %%
fig,axs = plt.subplots(2 ,2 ,figsize =(13, 10))
 
bp_fr=create_boxplot(data_FR,axs,0,0,"FR foot forces")
bp_fl=create_boxplot(data_FL,axs,0,1,"FL foot forces")
bp_br=create_boxplot(data_BR,axs,1,0,"BR foot forces")
bp_bl=create_boxplot(data_BL,axs,1,1,"BL foot forces")

# show plot
plt.show(bp_fr)

# %%
def print_std(data,pata):
    print("std Sinoidal",pata," :",np.mean(data[0]),"+-",np.std(data[0]))
    print("std Bezier",pata," :",np.mean(data[1]),"+-",np.std(data[1]))
    print("std Cicloidal",pata," :",np.mean(data[2]),"+-",np.std(data[2]))
    print("std Simple",pata," :",np.mean(data[3]),"+-",np.std(data[3]))

# %%
print_std(data_FR,"FR")
print_std(data_FL,"FL")
print_std(data_BR,"BR")
print_std(data_BL,"BL")
# Out:
# std Sinoidal FR  : 4.369724932030309 +- 6.704571852459159
# std Bezier FR  : 4.7557278323435295 +- 10.075454177020642
# std Cicloidal FR  : 4.784518854233928 +- 7.70373736442026
# std Simple FR  : 4.11936854052908 +- 5.884367820166867
# std Sinoidal FL  : 4.510601537601655 +- 6.939385635743621
# std Bezier FL  : 4.91259185238066 +- 9.785925259663419
# std Cicloidal FL  : 4.607233963528239 +- 7.813267641717894
# std Simple FL  : 4.136744824348763 +- 5.857516852721011
# std Sinoidal BR  : 6.234754812882778 +- 7.408342948351811
# std Bezier BR  : 6.727932129311138 +- 9.219458858281914
# std Cicloidal BR  : 6.204333616418747 +- 7.559035613476299
# std Simple BR  : 5.364322700107073 +- 6.52474368852709
# std Sinoidal BL  : 6.047527012921719 +- 7.343978800278937
# std Bezier BL  : 6.808500729003301 +- 9.378245069344386
# std Cicloidal BL  : 6.211909130077374 +- 7.360651500079324
# std Simple BL  : 4.612342848130512 +- 6.159138564135851
